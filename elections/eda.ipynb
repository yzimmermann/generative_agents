# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_stata('data and analyses/NEGex_1.0_candidates.dta')
df
# Out:
#          _SECT1_Actors                  actor     lastname         lastname2  \
# 0    --- SECTION 1 ---    Andri Snær Magnason     Magnason     Magnason [IS]
# 1    --- SECTION 1 ---          Davíð Oddsson      Oddsson      Oddsson [IS]
# 2    --- SECTION 1 ---  Guðni Th. Jóhannesson  Jóhannesson  Jóhannesson [IS]
# 3    --- SECTION 1 ---      Halla Tómasdóttir  Tómasdóttir  Tómasdóttir [IS]
# 4    --- SECTION 1 ---         Sturla Jónsson      Jónsson      Jónsson [IS]
# ..                 ...                    ...          ...               ...
# 368  --- SECTION 1 ---         Vladimir Putin        Putin        Putin [RU]
# 369  --- SECTION 1 ---         Pavel Grudinin     Grudinin     Grudinin [RU]
# 370  --- SECTION 1 ---   Vladimir Zhirinovsky  Zhirinovsky  Zhirinovsky [RU]
# 371  --- SECTION 1 ---         Ksenia Sobchak      Sobchak      Sobchak [RU]
# 372  --- SECTION 1 ---      Grigory Yavlinsky    Yavlinsky    Yavlinsky [RU]
#
# ...

# %%
df[["country", "election_date"]].groupby("country").nunique()
# Out:
#              election_date
# country
# Albania                  1
# Algeria                  1
# Argentina                1
# Armenia                  1
# Australia                1
# ...                    ...
# Timor Leste              2
# UK                       1
# USA                      1
# Uzbekistan               1
# Zambia                   1
#
# [62 rows x 1 columns]

# %%
for col in df.columns:
    print(col)
# Out:
# _SECT1_Actors
# actor
# lastname
# lastname2
# lastname3
# actornumber
# actortype
# electID
# country
# country_codeNEGex
# country_codeISOalpha2
# country_codeISOalpha3
# country_codeISOnum
# country_region
# election_date
# election_count
# election_type
# election_name
# _SECT2_ToneFT
# tone
# tone_CNP
# tone_CP
# ft
# _SECT3_Target
# target_twd1
# target_twd2
# target_twd3
# target_twd4
# target_twd5
# target_twd6
# target_twd7
# target_twd8
# target_twd9
# target_twd10
# target_twdnoone
# _SECT4_Issue
# isatk_i1
# isatk_i2
# isatk_i3
# isatk_i4
# isatk_i5
# isatk_i6
# isatk_i7
# isatk_i8
# isatk_i9
# isatk_i10
# _SECT5_Emotions
# feelgood
# fear
# _SECT6_BigFive
# bfi_extrav
# bfi_agree
# bfi_consc
# bfi_emot
# bfi_open
# bfi_c1
# bfi_c2
# bfi_c3
# bfi_c4
# bfi_c5
# bfi_c6
# bfi_c7
# bfi_c8
# bfi_c9
# bfi_c10
# _SECT7_DarkTriad
# triad_narciss
# triad_psycho
# triad_machiav
# triad_c1
# triad_c2
# triad_c3
# triad_c4
# triad_c5
# triad_c6
# _SECT8_Populism
# populism
# ...
